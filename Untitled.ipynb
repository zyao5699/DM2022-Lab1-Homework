# %%
import pandas as pd

# %%
covid_df = pd.read_csv('export.csv',engine ='python')
covid_df.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3832\2936936253.py in <module>
# ----> 1 covid_df = pd.read_csv('export.csv',engine ='python')
#       2 covid_df.head()
#
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
